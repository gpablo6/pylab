# %% [markdown]
# # Lesson 3: Enable Logging

# %% [markdown]
# ### Import all needed packages

# %%
import boto3
import json
import os

bedrock = boto3.client('bedrock', region_name="us-west-2")

# %%
from helpers.CloudWatchHelper import CloudWatch_Helper
cloudwatch = CloudWatch_Helper()

# %%
log_group_name = '/my/amazon/bedrock/logs'

# %%
cloudwatch.create_log_group(log_group_name)
# Out:
# Log group '/my/amazon/bedrock/logs' created successfully.

# %%
loggingConfig = {
    'cloudWatchConfig': {
        'logGroupName': log_group_name,
        'roleArn': os.environ['LOGGINGROLEARN'],
        'largeDataDeliveryS3Config': {
            'bucketName': os.environ['LOGGINGBUCKETNAME'],
            'keyPrefix': 'amazon_bedrock_large_data_delivery',
        }
    },
    's3Config': {
        'bucketName': os.environ['LOGGINGBUCKETNAME'],
        'keyPrefix': 'amazon_bedrock_logs',
    },
    'textDataDeliveryEnabled': True,
}

# %%
bedrock.put_model_invocation_logging_configuration(loggingConfig=loggingConfig)
# Out:
# {'ResponseMetadata': {'RequestId': '9c117b34-d2b0-4702-8b77-9922576d08e3',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Thu, 16 Oct 2025 22:46:53 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '9c117b34-d2b0-4702-8b77-9922576d08e3'},
#   'RetryAttempts': 0}}

# %%
bedrock.get_model_invocation_logging_configuration()
# Out:
# {'ResponseMetadata': {'RequestId': '88b30203-9fa5-46cc-9e8d-f8c37fac62c8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Thu, 16 Oct 2025 22:46:56 GMT',
#    'content-type': 'application/json',
#    'content-length': '604',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '88b30203-9fa5-46cc-9e8d-f8c37fac62c8'},
#   'RetryAttempts': 0},
#  'loggingConfig': {'cloudWatchConfig': {'logGroupName': '/my/amazon/bedrock/logs',
#    'roleArn': 'arn:aws:iam::180191224060:role/c99355a2566044l12092225t1w7695346842-LoggingIAMRole-7sIoxzerj3YQ',
#    'largeDataDeliveryS3Config': {'bucketName': 'c99355a2566044l12092225t1w76953468-loggings3bucket-ifq1rwmy78az',
#     'keyPrefix': 'amazon_bedrock_large_data_delivery'}},
#   's3Config': {'bucketName': 'c99355a2566044l12092225t1w76953468-loggings3bucket-ifq1rwmy78az',
#    'keyPrefix': 'amazon_bedrock_logs'},
#   'textDataDeliveryEnabled': True,
#   'imageDataDeliveryEnabled': True,
#   'embeddingDataDeliveryEnabled': True}}

# %%
bedrock_runtime = boto3.client('bedrock-runtime', region_name="us-west-2")

# %%
prompt = "Write an article about the fictional planet Foobar."

kwargs = {
    "modelId": "amazon.titan-text-express-v1",
    "contentType": "application/json",
    "accept": "*/*",
    "body": json.dumps(
        {
            "inputText": prompt,
            "textGenerationConfig": {
                "maxTokenCount": 512,
                "temperature": 0.7,
                "topP": 0.9
            }
        }
    )
}

response = bedrock_runtime.invoke_model(**kwargs)
response_body = json.loads(response.get('body').read())

generation = response_body['results'][0]['outputText']

print(generation)
# Out:
# Foobar is a fictional planet in the Star Trek universe. It is the homeworld of the Ferengi, a species of aliens known for their greedy and materialistic nature. Foobar is a small planet, with a rocky surface and a thin atmosphere. It has a single moon, which is named after the Ferengi god of wealth, Q'plah.
#
# The Ferengi are a highly advanced species that have mastered many technologies, including warp drive, hyperspace travel, and replicators. They are also known for their strict economic system, which revolves around the accumulation of wealth and the exploitation of others. The Ferengi live in a highly stratified society, with a small elite at the top and a vast majority of the population living in poverty.
#
# Foobar is a key location in the Star Trek universe, as it is the site of many important events and conflicts. For example, it is the location of the Ferengi Alliance, a powerful political and economic organization that controls much of the galaxy. The Ferengi also play a significant role in the Star Trek: The Next Generation episode "The Price," in which they attempt to negotiate a trade deal with the Federation.
#
# Despite their negative reputation, the Ferengi are not entirely evil. They have a strong sense of family and community, and they are often willing to help those in need. They also have a rich cultural heritage, with many traditions and customs that are passed down from generation to generation.
#
# However, the Ferengi's greed and materialism have led to many problems in the Star Trek universe. They have often engaged in unscrupulous practices, such as fraud, extortion, and piracy. They have also been involved in conflicts with other species, including the Federation, the Klingons, and the Romulans.
#
# In recent years, the Ferengi have been undergoing a significant change. They have begun to embrace a more ethical and moral approach to economics, and they have even joined the Federation as a member species. This has led to some tension between the Ferengi and other members of the Federation, but it has also opened up new opportunities for cooperation and exploration.
#
# Despite their negative reputation, the Ferengi are a fascinating and complex species. They have a unique perspective on the universe, and they have played a significant role in the Star Trek universe. Whether you love them or hate them, the Ferengi are a species that is worth exploring.

# %%
cloudwatch.print_recent_logs(log_group_name)
# Out:
# Permissions are correctly set for Amazon Bedrock logs.
# -------------------------
#
# {
#     "timestamp": "2025-10-16T22:47:14Z",
#     "accountId": "180191224060",
#     "identity": {
#         "arn": "arn:aws:sts::180191224060:assumed-role/voclabs/user4486141=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhcHA"
#     },
#     "region": "us-west-2",
#     "requestId": "147e8ded-85d8-422e-bc1b-f6ea91fe23a6",
#     "operation": "InvokeModel",
#     "modelId": "amazon.titan-text-express-v1",
#     "input": {
#         "inputContentType": "application/json",
#         "inputBodyJson": {
#             "inputText": "Write an article about the fictional planet Foobar.",
#             "textGenerationConfig": {
#                 "maxTokenCount": 512,
#                 "temperature": 0.7,
#                 "topP": 0.9
#             }
#         },
#         "inputTokenCount": 10
#     },
#     "output": {
#         "outputContentType": "application/json",
#         "outputBodyJson": {
#             "inputTextTokenCount": 10,
#             "results": [
#                 {
#                     "tokenCount": 494,
#                     "outputText": "\nFoobar is a fictional planet in the Star Trek universe. It is the homeworld of the Ferengi, a species of aliens known for their greedy and materialistic nature. Foobar is a small planet, with a rocky surface and a thin atmosphere. It has a single moon, which is named after the Ferengi god of wealth, Q'plah.\n\nThe Ferengi are a highly advanced species that have mastered many technologies, including warp drive, hyperspace travel, and replicators. They are also known for their strict economic system, which revolves around the accumulation of wealth and the exploitation of others. The Ferengi live in a highly stratified society, with a small elite at the top and a vast majority of the population living in poverty.\n\nFoobar is a key location in the Star Trek universe, as it is the site of many important events and conflicts. For example, it is the location of the Ferengi Alliance, a powerful political and economic organization that controls much of the galaxy. The Ferengi also play a significant role in the Star Trek: The Next Generation episode \"The Price,\" in which they attempt to negotiate a trade deal with the Federation.\n\nDespite their negative reputation, the Ferengi are not entirely evil. They have a strong sense of family and community, and they are often willing to help those in need. They also have a rich cultural heritage, with many traditions and customs that are passed down from generation to generation.\n\nHowever, the Ferengi's greed and materialism have led to many problems in the Star Trek universe. They have often engaged in unscrupulous practices, such as fraud, extortion, and piracy. They have also been involved in conflicts with other species, including the Federation, the Klingons, and the Romulans.\n\nIn recent years, the Ferengi have been undergoing a significant change. They have begun to embrace a more ethical and moral approach to economics, and they have even joined the Federation as a member species. This has led to some tension between the Ferengi and other members of the Federation, but it has also opened up new opportunities for cooperation and exploration.\n\nDespite their negative reputation, the Ferengi are a fascinating and complex species. They have a unique perspective on the universe, and they have played a significant role in the Star Trek universe. Whether you love them or hate them, the Ferengi are a species that is worth exploring.",
#                     "completionReason": "FINISH"
#                 }
#             ]
#         },
#         "outputTokenCount": 494
#     },
#     "schemaType": "ModelInvocationLog",
#     "schemaVersion": "1.0"
# }
# -------------------------

# %% [markdown]
# To review the logs within the AWS console, please use the following link to reference the steps outlined in the video:

# %%
from IPython.display import HTML
aws_url = os.environ['AWS_CONSOLE_URL']

# %%
HTML(f'<a href="{aws_url}" target="_blank">GO TO AWS CONSOLE</a>')
# Out:
# <a href="https://signin.aws.amazon.com/federation?Action=login&SigninToken=DsabsRWrLGvkG39EVhisUmMy_aQM4cR5QL3KLwzgFeC2yZkRkm6qtXAU5SYUm7Qsiu0C8FfENfTMpc9-HW7jONDRt7UAgU1zp6jeexaQgYI1EqiQ8o2g_BGbxRnZcPdTRTzWXwBDb7bAcTA47yW-w8MZmPKdS35r41ctr6n0TuuW17s6AJPOuzhW4gSCyLo2pvMVDnIYhnTi-t46pMWIzI797B3KtpO89Zwj-f0ignd-MhkcvowHjNoSIa4kna5NszzZivZYB6nq1qDcO_OEZ_rxuYxCH0e5km3Mmd924Wqc3KVDkvm_60BY0RNcop2bHa1jPiheKOcP1QsD24d_JE78SX_aDxwskz2F3ZutRwnQwQWY4W5YiAGJDMO8nzRhMrRJt5HFzahffZhoxDvnTwrc62HpToJ-A8ivt_orMUvbxTpKG8XjAUq3KoGoIOqwy-DTa7sZhdde9iWJWJP5tKUcZuyhwgZVhFrlfjvrUUg_QXOfeW38O1_CoP4Zl1xOvNwaGJZ_DxRwGJvNZQgUkEnZn70OZ_0ZOIPXwBUTWmpDiY6DF1nDTqMub-7EIEuXxCR_upv3NkyiZU2nXlioHZWHvZBLe4sWz6ou8pY5u9wARPdj35jSy7pUQ7oOOHaMYhgyMvUwk5gXp4FIfyzpxfqPszxgUiZizCAoLP7DfOP1uric3c0O6SMeNzhlTBVhoANKzECTN2Zd31CKUY7Dh_qCj7vm1f56gofBIrkbpOjvNZKf0qOmE4epRPy1DOW0gLnCUNxTAmXNt1-k4z298jwMntn7nbE-sg-l1aJxQ93NriT63gsVeZrnqdwKXOIfD_O95ihTu7HUm1U_A53BGuLsnQiR4lnPyqXMWVC11BJM3avGOJnFN9tBtB-cu1AJRw2zYfFfTQoCI_5ZZHP-wFiOduFWIj4BDUF8f3ymy5Llr--qNeyjfWHpAzoZLBPc64r3oef_iwZRXYC_a7fj6gjSbaVZAHBTXpB0lPzJUUXn2KpME644J4YhZa6AHMaa3qD-uZXfMdYjKVPfU2chPfE0K6rf-nWIPtpZEqjmIlXuoUZgtPNYfycAPXIOUtiGdl-Q13nqm07HHoEQZ_3uX4y4U3_uyrAXkfX4NaexrvFkXMAPDF0ou57RpBksYnfXYHzMnlQy_tDgRkxapXeTkeLwf18rQVWbmURS5oYO-8bPgth4JzeVkitQkQa5ZVbg-VVZ4f-oHO4jkulCOWVeuFfBvPLeKDqMsX7Tw7kPDyzW5ratucFL0W2Fj6WP5elMfK2egS2wLy70qQzaiEdn4ugBbtJqm0NvC7LekvPmCAGBGvAkrx5YN8iugWqEHH1EEV0KD__izG2YjC-V_x-fXe7qks291n4MaqWuVb1gTDf6hmXnDDDUbZW2hoAOFSVCXJ091ADQnRbBFMsFoDQI7CPK2hzEfqQap2En76lhWK56FvYKUlfE-aENcxqZW3oz5aMG4PO8ARy4TMW8xLDCWB38FrQVu9Ld53bF-_osXcVwldh09mxeiWIyLaNl_3GSVR8x8A861hvGzbzJmgt4ruOipkGi_Es&Issuer=https%3A%2F%2Fapi.vocareum.com&Destination=https%3A%2F%2Fconsole.aws.amazon.com%2Fconsole%2Fhome%3Fregion%3Dus-west-2" target="_blank">GO TO AWS CONSOLE</a>
